# %%
def isPrime(a):
    if a<2:
        return False
    for i in range(2,a):
        if i*i>a:
            return False
        if a%i==0:
            return True
    return False

isPrime(11)
# Out:
# False

# %%
import random
def millerRabin(n):
    if n<3:
        return n==2
    test_time=12
    for i in range(1,test_time+1):
        a=random.randint()%(n-2)+2
        if quic
