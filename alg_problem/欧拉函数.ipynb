# %%
def euler_phi(n):
    m=int(n**0.5)
    ans=n
    for i in range(2,m+1):
        if n%i==0:
            ans=ans//i*(i-1)
            while n%i==0:
                n/=i
    if n>1:
        ans=ans/n*(n-1)
    return int(ans)

euler_phi(10)
# Out:
# 4
