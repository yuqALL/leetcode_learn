# %%
Given a 2D board and a list of words from the dictionary, find all words in the board.

Each word must be constructed from letters of sequentially adjacent cell, where "adjacent" cells are those horizontally or vertically neighboring. The same letter cell may not be used more than once in a word.

 

Example:

Input: 
board = [
  ['o','a','a','n'],
  ['e','t','a','e'],
  ['i','h','k','r'],
  ['i','f','l','v']
]
words = ["oath","pea","eat","rain"]

Output: ["eat","oath"]
 

Note:

All inputs are consist of lowercase letters a-z.
The values of words are distinct.

来源：力扣（LeetCode）
链接：https://leetcode-cn.com/problems/word-search-ii
著作权归领扣网络所有。商业转载请联系官方授权，非商业转载请注明出处。

# %%
#DFS超时

from typing import List

class Solution:

    def dfs(self,board,visited,pos,word,N,M):
        if not word:
            return True
        x,y=pos
        visited.add((x,y))
        havenext=False
        for dx,dy in [(-1,0),(1,0),(0,-1),(0,1)]:
            x2,y2=x+dx,y+dy
            if 0<=x2<N and 0<=y2<M and (x2,y2) not in visited and board[x2][y2]==word[0]:
                havenext=True
                if self.dfs(board,visited,(x2,y2),word[1:],N,M):
                    return True
        visited.remove((x,y))
        return False

    def bfs(self,board,visited,pos,word,N,M):
        if not word:
            return True
        from collections import deque
        queue=deque()
        queue.append((pos,word))
        while queue:
            (x,y),w = queue.popleft()
            if not w:
                return True
            havenext=False
            visited.add((x,y))
            for dx,dy in [(-1,0),(1,0),(0,-1),(0,1)]:
                x2,y2=x+dx,y+dy
                if 0<=x2<N and 0<=y2<M and (x2,y2) not in visited and board[x2][y2]==word[0]:
                    havenext=True
                    queue.append(((x2,y2),w[1:])) 
            #何时删除？这里BFS貌似难以实现功能
            visited.remove((x,y))         
                
    def findWords(self, board: List[List[str]], words: List[str]) -> List[str]:
        result=[]
        N=len(board)
        M=len(board[0])
        for word in words:
            have=False
            for i in range(N):
                for j in range(M):
                    if board[i][j]==word[0]:
                        visited=set()
                        have=self.dfs(board,visited,(i,j),word[1:],N,M)
                        if have:
                            result.append(word)
                            break
                if have:
                    break
                
        return result

# board = [
#    ['o','a','a','n'],
#   ['e','t','a','e'],
#   ['i','h','k','r'],
#   ['i','f','l','v']
# ]
# words = ["oath","pea","eat","rain"]

board2=[["a","a"]]
words2=["aaa"]

board3=[
    ["b","a","a","b","a","b"],
    ["a","b","a","a","a","a"],
    ["a","b","a","a","a","b"],
    ["a","b","a","b","b","a"],
    ["a","a","b","b","a","b"],
    ["a","a","b","b","b","a"],
    ["a","a","b","a","a","b"]]

words3=["aabbbbabbaababaaaabababbaaba","abaabbbaaaaababbbaaaaabbbaab","ababaababaaabbabbaabbaabbaba"]
Solution().findWords(board3,words3)
# Out:
# ['aabbbbabbaababaaaabababbaaba',
#  'abaabbbaaaaababbbaaaaabbbaab',
#  'ababaababaaabbabbaabbaabbaba']

# %%
class Solution:
    def dfs(self,board,visited,pos,word,N,M):
        if not word:
            return True
        visited.add(pos)
        for dx,dy in [(-1,0),(1,0),(0,-1),(0,1)]:
            x2,y2=pos[0]+dx,pos[1]+dy
            if 0<=x2<N and 0<=y2<M and (x2,y2) not in visited and board[x2][y2]==word[0]:
                if self.dfs(board,visited,(x2,y2),word[1:],N,M):
                    return True
        visited.remove(pos)
        return False  

    def findWords(self, board: List[List[str]], words: List[str]) -> List[str]:
        result=[]
        N=len(board)
        M=len(board[0])
        for word in words:
            for p in range(N*M):
                if board[p//M][p%M]==word[0]:
                    visited=set()
                    have=self.dfs(board,visited,(p//M,p%M),word[1:],N,M)
                    if have:
                        result.append(word)
                        break
        return result

board2=[["a","a"]]
words2=["aaa"]
board3=[
    ["b","a","a","b","a","b"],
    ["a","b","a","a","a","a"],
    ["a","b","a","a","a","b"],
    ["a","b","a","b","b","a"],
    ["a","a","b","b","a","b"],
    ["a","a","b","b","b","a"],
    ["a","a","b","a","a","b"]]

words3=["aabbbbabbaababaaaabababbaaba","abaabbbaaaaababbbaaaaabbbaab","ababaababaaabbabbaabbaabbaba"]
Solution().findWords(board3,words3)
# Out:
# ['aabbbbabbaababaaaabababbaaba',
#  'abaabbbaaaaababbbaaaaabbbaab',
#  'ababaababaaabbabbaabbaabbaba']

# %%
#不使用HashSet试试？依然超时
class Solution:
    def dfs(self,board,pos,word,N,M):
        if not word:
            return True
        temp=board[pos[0]][pos[1]]
        board[pos[0]][pos[1]]='#'
        for dx,dy in [(-1,0),(1,0),(0,-1),(0,1)]:
            x2,y2=pos[0]+dx,pos[1]+dy
            if 0<=x2<N and 0<=y2<M and board[x2][y2]==word[0]:
                if self.dfs(board,(x2,y2),word[1:],N,M):
                    board[pos[0]][pos[1]]=temp
                    return True
        board[pos[0]][pos[1]]=temp
        return False  

    def findWords(self, board: List[List[str]], words: List[str]) -> List[str]:
        result=[]
        N=len(board)
        M=len(board[0])
        for word in words:
            for p in range(N*M):
                if board[p//M][p%M]==word[0]:
                    have=self.dfs(board,(p//M,p%M),word[1:],N,M)
                    if have:
                        result.append(word)
                        break
        return result

board2=[["a","a"]]
words2=["aaa"]
board3=[
    ["b","a","a","b","a","b"],
    ["a","b","a","a","a","a"],
    ["a","b","a","a","a","b"],
    ["a","b","a","b","b","a"],
    ["a","a","b","b","a","b"],
    ["a","a","b","b","b","a"],
    ["a","a","b","a","a","b"]]

words3=["aabbbbabbaababaaaabababbaaba","abaabbbaaaaababbbaaaaabbbaab","ababaababaaabbabbaabbaabbaba"]
Solution().findWords(board3,words3)
# Out:
# ['aabbbbabbaababaaaabababbaaba',
#  'abaabbbaaaaababbbaaaaabbbaab',
#  'ababaababaaabbabbaabbaabbaba']

# %%
#前缀树
#此算法将表中所有可能生成的单词加入前缀树，然后查询单词
#生成前缀树太慢了，随board大小几何倍数增加
class TrieNode:

    def __init__(self):
        self.next=[None for _ in range(26)]
    def __repr__(self):
        s=[]
        for i,nd in enumerate(self.next):
            if nd:
                s.append(chr(97+i))
        return "node:{}".format(s)

class Solution:
    def dfs(self,board,visited,pos,cur,N,M):
        if not cur:
            cur=TrieNode()
        visited.add(pos)
        for dx,dy in [(-1,0),(1,0),(0,-1),(0,1)]:
            x2,y2=pos[0]+dx,pos[1]+dy
            if 0<=x2<N and 0<=y2<M and (x2,y2) not in visited:
                ind=ord(board[x2][y2])-ord('a') 
                cur.next[ind]=self.dfs(board,visited,(x2,y2),cur.next[ind],N,M)
        visited.remove(pos)
        return cur

    def create_trie(self,board):
        root=TrieNode()
        N=len(board)
        M=len(board[0])
        for i in range(N):
            for j in range(M):
                visited=set()
                ind=ord(board[i][j])-ord('a')
                root.next[ind]=self.dfs(board,visited,(i,j),root.next[ind],N,M)
        return root

    def findWords(self, board: List[List[str]], words: List[str]) -> List[str]:
        result=[]
        trie_root=self.create_trie(board)
        cur=trie_root
        for word in words:
            cur=trie_root
            have=True
            for v in word:
                if not cur.next[ord(v)-ord('a')]:
                    have=False
                    break
                cur=cur.next[ord(v)-ord('a')]
            if have:
                result.append(word)
        return result
board = [
    ['o','a','a','n'],
    ['e','t','a','e'],
    ['i','h','k','r'],
    ['i','f','l','v']
]
words = ["oath","pea","eat","rain"]

board2=[["a","a"]]
words2=["aa"]
board3=[
    ["b","a","a","b","a","b"],
    ["a","b","a","a","a","a"],
    ["a","b","a","a","a","b"],
    ["a","b","a","b","b","a"],
    ["a","a","b","b","a","b"],
    ["a","a","b","b","b","a"],
    ["a","a","b","a","a","b"]]

words3=["aabbbbabbaababaaaabababbaaba","abaabbbaaaaababbbaaaaabbbaab","ababaababaaabbabbaabbaabbaba"]
Solution().findWords(board,words)
# Out:
# ['oath', 'eat']

# %%
#前缀树
#将所有需要查询的单词放入前缀树，在遍历表中节点，看是否遇到某个单词

class TrieNode:
    def __init__(self):
        self.e=0
        self.next=[None for _ in range(26)]
    def __repr__(self):
        s=[]
        for i,nd in enumerate(self.next):
            if nd:
                s.append(chr(97+i))
        return "e:{} next:{}".format(self.e,s)

class Solution:
    def dfs(self,board,visited,pos,cur,current_word,result,N,M):
        visited.add(pos)
        current_word.append(board[pos[0]][pos[1]])
        if cur.e>0:
            result.add(''.join([v for v in current_word]))
        for dx,dy in [(-1,0),(1,0),(0,-1),(0,1)]:
            x2,y2=pos[0]+dx,pos[1]+dy
            if 0<=x2<N and 0<=y2<M and (x2,y2) not in visited:
                ind=ord(board[x2][y2])-ord('a')
                if cur.next[ind]:
                    self.dfs(board,visited,(x2,y2),cur.next[ind],current_word,result,N,M)
                    current_word.pop()
                    
        visited.remove(pos)
        return

    def create_trie(self,words):
        root=TrieNode()
        for word in words:
            cur=root
            n=len(word)
            for i,v in enumerate(word):
                ind=ord(v)-ord('a')
                if not cur.next[ind]:
                    cur.next[ind]=TrieNode()
                cur=cur.next[ind]
                if i==n-1:
                    cur.e+=1
        return root

    def findWords(self, board: List[List[str]], words: List[str]) -> List[str]:
        result=set()
        trie_root=self.create_trie(words)
        N=len(board)
        M=len(board[0])

        for i in range(N):
            for j in range(M):
                cur=trie_root
                ind=ord(board[i][j])-ord('a')
                if cur.next[ind]:
                    current_word=[]
                    visited=set()
                    self.dfs(board,visited,(i,j),cur.next[ind],current_word,result,N,M)
           
        return list(result)
board = [
    ['o','a','a','n'],
    ['e','t','a','e'],
    ['i','h','k','r'],
    ['i','f','l','v']
]
words = ["oath","pea","eat","rain"]

board3=[
    ["b","a","a","b","a","b"],
    ["a","b","a","a","a","a"],
    ["a","b","a","a","a","b"],
    ["a","b","a","b","b","a"],
    ["a","a","b","b","a","b"],
    ["a","a","b","b","b","a"],
    ["a","a","b","a","a","b"]]

words3=["aabbbb","abaabbbaaaa","ababaababaa"]
Solution().findWords(board3,words3)
# Out:
# ['aabbbb', 'abaabbbaaaa', 'ababaababaa']

# %%
#前缀树
#将所有需要查询的单词放入前缀树，在遍历表中节点，看是否遇到某个单词
#不使用HashSet

class TrieNode:
    def __init__(self):
        self.e=0
        self.next=[None for _ in range(26)]
    def __repr__(self):
        s=[]
        for i,nd in enumerate(self.next):
            if nd:
                s.append(chr(97+i))
        return "e:{} next:{}".format(self.e,s)

class Solution:
    def dfs(self,board,pos,cur,current_word,result,N,M):
        
        current_word.append(board[pos[0]][pos[1]])
        temp=board[pos[0]][pos[1]]
        board[pos[0]][pos[1]]='#'
        if cur.e>0:
            result.add(''.join([v for v in current_word]))
        for dx,dy in [(-1,0),(1,0),(0,-1),(0,1)]:
            x2,y2=pos[0]+dx,pos[1]+dy
            if 0<=x2<N and 0<=y2<M and board[x2][y2]!='#' and cur.next[ord(board[x2][y2])-ord('a')]:
                self.dfs(board,(x2,y2),cur.next[ord(board[x2][y2])-ord('a')],current_word,result,N,M)
                current_word.pop()
                    
        board[pos[0]][pos[1]]=temp
        return

    def create_trie(self,words):
        root=TrieNode()
        for word in words:
            cur=root
            n=len(word)
            for i,v in enumerate(word):
                ind=ord(v)-ord('a')
                if not cur.next[ind]:
                    cur.next[ind]=TrieNode()
                cur=cur.next[ind]
                if i==n-1:
                    cur.e+=1
        return root

    def findWords(self, board: List[List[str]], words: List[str]) -> List[str]:
        result=set()
        trie_root=self.create_trie(words)
        N=len(board)
        M=len(board[0])

        for i in range(N):
            for j in range(M):
                cur=trie_root
                ind=ord(board[i][j])-ord('a')
                if cur.next[ind]:
                    current_word=[]
                    visited=set()
                    self.dfs(board,(i,j),cur.next[ind],current_word,result,N,M)
           
        return list(result)
board = [
    ['o','a','a','n'],
    ['e','t','a','e'],
    ['i','h','k','r'],
    ['i','f','l','v']
]
words = ["oath","pea","eat","rain"]

board3=[
    ["b","a","a","b","a","b"],
    ["a","b","a","a","a","a"],
    ["a","b","a","a","a","b"],
    ["a","b","a","b","b","a"],
    ["a","a","b","b","a","b"],
    ["a","a","b","b","b","a"],
    ["a","a","b","a","a","b"]]

words3=["aabbbb","abaabbbaaaa","ababaababaa"]
Solution().findWords(board3,words3)
# Out:
# ['aabbbb', 'abaabbbaaaa', 'ababaababaa']

# %%
class Solution:
    def findWords(self, board: List[List[str]], words: List[str]) -> List[str]:
        def dfs(i, j, t, s):
            ch = board[i][j]
            if ch not in t:
                return
            t = t[ch]
            if "end" in t and t["end"] == 1:
                res.append(s+ch)
                t["end"] = 0#这句没想到，去重更简单了
            board[i][j] = "#"
            if i + 1 < m and board[i+1][j] != "#":
                dfs(i+1, j, t, s+ch)
            if i - 1 >= 0 and board[i-1][j] != "#":
                dfs(i-1, j, t, s+ch)
            if j + 1 < n and board[i][j+1] != "#":
                dfs(i, j+1, t, s+ch)
            if j - 1 >= 0 and board[i][j-1] != "#":
                dfs(i, j-1, t, s+ch)
            board[i][j] = ch
        
        # 将word存入前缀树    
        trie = {}
        for word in words:
            t = trie
            for ch in word:
                if ch not in t:
                    t[ch] = {}
                t = t[ch]
            t["end"] = 1
        
        m = len(board)
        n = len(board[0])
        res = []
        # 对board进行深度优先搜索
        for i in range(m):
            for j in range(n):
                dfs(i, j, trie, "")
        return res
board3=[
    ["b","a","a","b","a","b"],
    ["a","b","a","a","a","a"],
    ["a","b","a","a","a","b"],
    ["a","b","a","b","b","a"],
    ["a","a","b","b","a","b"],
    ["a","a","b","b","b","a"],
    ["a","a","b","a","a","b"]]

words3=["aabbbb","abaabbbaaaa","ababaababaa"]
Solution().findWords(board3,words3)

# 作者：jia-zhi-tong-1
# 链接：https://leetcode-cn.com/problems/word-search-ii/solution/qian-zhui-shu-shen-du-you-xian-sou-suo-by-jia-zhi-/
# 来源：力扣（LeetCode）
# 著作权归作者所有。商业转载请联系作者获得授权，非商业转载请注明出处。
# Out:
# ['ababaababaa', 'abaabbbaaaa', 'aabbbb']

# %%
#前缀树
#将所有需要查询的单词放入前缀树，在遍历表中节点，看是否遇到某个单词
#不使用HashSet

class TrieNode:
    def __init__(self):
        self.e=0
        self.next=[None for _ in range(26)]
    def __repr__(self):
        s=[]
        for i,nd in enumerate(self.next):
            if nd:
                s.append(chr(97+i))
        return "e:{} next:{}".format(self.e,s)

class Solution:
    def dfs(self,board,pos,cur,s,result,N,M):

        ch=board[pos[0]][pos[1]]
        board[pos[0]][pos[1]]='#'
        if cur.e>0:
            result.append(s+ch)
            cur.e-=1
        for dx,dy in [(-1,0),(1,0),(0,-1),(0,1)]:
            x2,y2=pos[0]+dx,pos[1]+dy
            if 0<=x2<N and 0<=y2<M and board[x2][y2]!='#' and cur.next[ord(board[x2][y2])-ord('a')]:
                self.dfs(board,(x2,y2),cur.next[ord(board[x2][y2])-ord('a')],s+ch,result,N,M)
                    
        board[pos[0]][pos[1]]=ch
        return

    def create_trie(self,words):
        root=TrieNode()
        for word in words:
            cur=root
            n=len(word)
            for i,v in enumerate(word):
                ind=ord(v)-ord('a')
                if not cur.next[ind]:
                    cur.next[ind]=TrieNode()
                cur=cur.next[ind]
                if i==n-1:
                    cur.e+=1
        return root

    def findWords(self, board: List[List[str]], words: List[str]) -> List[str]:
        result=[]
        trie_root=self.create_trie(words)
        N=len(board)
        M=len(board[0])

        for i in range(N):
            for j in range(M):
                cur=trie_root
                ind=ord(board[i][j])-ord('a')
                if cur.next[ind]:
                    self.dfs(board,(i,j),cur.next[ind],"",result,N,M)
           
        return result
board = [
    ['o','a','a','n'],
    ['e','t','a','e'],
    ['i','h','k','r'],
    ['i','f','l','v']
]
words = ["oath","pea","eat","rain"]

board3=[
    ["b","a","a","b","a","b"],
    ["a","b","a","a","a","a"],
    ["a","b","a","a","a","b"],
    ["a","b","a","b","b","a"],
    ["a","a","b","b","a","b"],
    ["a","a","b","b","b","a"],
    ["a","a","b","a","a","b"]]

words3=["aabbbb","abaabbbaaaa","ababaababaa"]
Solution().findWords(board,words)
# Out:
# ['oath', 'eat']

# %%
class TrieNode:
    def __init__(self):
        self.e=0
        self.next={}

class Solution:

    def findWords(self, board: List[List[str]], words: List[str]) -> List[str]:
        result=[]
        
        N=len(board)
        M=len(board[0])

        def create_trie():
            root=TrieNode()
            for word in words:
                cur=root
                n=len(word)
                for i,v in enumerate(word):
                    if v not in cur.next:
                        cur.next[v]=TrieNode()
                    cur=cur.next[v]
                    if i==n-1:
                        cur.e+=1
            return root

        trie_root=create_trie()

        def dfs(pos,cur,s):

            ch=board[pos[0]][pos[1]]
            board[pos[0]][pos[1]]='#'
            if cur.e>0:
                result.append(s+ch)
                cur.e-=1
            for dx,dy in [(-1,0),(1,0),(0,-1),(0,1)]:
                x2,y2=pos[0]+dx,pos[1]+dy
                if 0<=x2<N and 0<=y2<M and board[x2][y2]!='#' and board[x2][y2] in cur.next:
                    dfs((x2,y2),cur.next[board[x2][y2]],s+ch)
                        
            board[pos[0]][pos[1]]=ch
            return

        for i in range(N):
            for j in range(M):
                cur=trie_root
                if board[i][j] in cur.next:
                    dfs((i,j),cur.next[board[i][j]],"")
           
        return result
board = [
    ['o','a','a','n'],
    ['e','t','a','e'],
    ['i','h','k','r'],
    ['i','f','l','v']
]
words = ["oath","pea","eat","rain"]

board3=[
    ["b","a","a","b","a","b"],
    ["a","b","a","a","a","a"],
    ["a","b","a","a","a","b"],
    ["a","b","a","b","b","a"],
    ["a","a","b","b","a","b"],
    ["a","a","b","b","b","a"],
    ["a","a","b","a","a","b"]]

words3=["aabbbb","abaabbbaaaa","ababaababaa"]
Solution().findWords(board,words)
# Out:
# ['oath', 'eat']
